# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# 정규분포

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
np.linspace(0,10,100)
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
x = np.linspace(0,10,100)

# %%
y = 2 * x

# %%
y
# Out:
# array([ 0.        ,  0.2020202 ,  0.4040404 ,  0.60606061,  0.80808081,
#         1.01010101,  1.21212121,  1.41414141,  1.61616162,  1.81818182,
#         2.02020202,  2.22222222,  2.42424242,  2.62626263,  2.82828283,
#         3.03030303,  3.23232323,  3.43434343,  3.63636364,  3.83838384,
#         4.04040404,  4.24242424,  4.44444444,  4.64646465,  4.84848485,
#         5.05050505,  5.25252525,  5.45454545,  5.65656566,  5.85858586,
#         6.06060606,  6.26262626,  6.46464646,  6.66666667,  6.86868687,
#         7.07070707,  7.27272727,  7.47474747,  7.67676768,  7.87878788,
#         8.08080808,  8.28282828,  8.48484848,  8.68686869,  8.88888889,
#         9.09090909,  9.29292929,  9.49494949,  9.6969697 ,  9.8989899 ,
#        10.1010101 , 10.3030303 , 10.50505051, 10.70707071, 10.90909091,
#        11.11111111, 11.31313131, 11.51515152, 11.71717172, 11.91919192,
#        12.12121212, 12.32323232, 12.52525253, 12.72727273, 12.92929293,
#        13.13131313, 13.33333333, 13.53535354, 13.73737374, 13.93939394,
#        14.14141414, 14.34343434, 14.54545455, 14.74747475, 14.94949495,
#        15.15151515, 15.35353535, 15.55555556, 15.75757576, 15.95959596,
#        16.16161616, 16.36363636, 16.56565657, 16.76767677, 16.96969697,
#        17.17171717, 17.37373737, 17.57575758, 17.77777778, 17.97979798,
#        18.18181818, 18.38383838, 18.58585859, 18.78787879, 18.98989899,
#        19.19191919, 19.39393939, 19.5959596 , 19.7979798 , 20.        ])

# %%
plt.figure(figsize=(5,5))
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y)
plt.show()

# %%
# help(plt.plot)

# %%
plt.figure(figsize=(8,4))
plt.plot(x,y,'.--g')
plt.show()

# %%
y = x**2

# %%
x = np.linspace(-3,3,100)

# %%
y = x**2

# %%
plt.figure(figsize=(8,4))
plt.plot(x,y,'.--g')
plt.show()

# %%
sigma =1.0
m=0.0

# %%
y = (1.0 / (np.sqrt(2.0*np.pi*sigma)))*np.exp(1.0)**(- (x-m)**2.0/(2.0*sigma**2.0))

# %%
y
# Out:
# array([0.00443185, 0.00530579, 0.00632878, 0.00752133, 0.00890582,
#        0.0105065 , 0.01234943, 0.01446241, 0.01687483, 0.01961746,
#        0.02272223, 0.02622189, 0.03014961, 0.03453857, 0.03942137,
#        0.0448295 , 0.05079264, 0.05733801, 0.06448952, 0.07226707,
#        0.08068571, 0.08975477, 0.09947714, 0.10984842, 0.12085626,
#        0.13247967, 0.14468855, 0.15744319, 0.17069405, 0.18438164,
#        0.1984366 , 0.21277993, 0.22732351, 0.24197072, 0.2566174 ,
#        0.27115285, 0.28546117, 0.29942268, 0.31291556, 0.3258175 ,
#        0.33800759, 0.34936814, 0.35978656, 0.36915722, 0.37738323,
#        0.38437808, 0.3900672 , 0.39438923, 0.39729716, 0.39875915,
#        0.39875915, 0.39729716, 0.39438923, 0.3900672 , 0.38437808,
#        0.37738323, 0.36915722, 0.35978656, 0.34936814, 0.33800759,
#        0.3258175 , 0.31291556, 0.29942268, 0.28546117, 0.27115285,
#        0.2566174 , 0.24197072, 0.22732351, 0.21277993, 0.1984366 ,
#        0.18438164, 0.17069405, 0.15744319, 0.14468855, 0.13247967,
#        0.12085626, 0.10984842, 0.09947714, 0.08975477, 0.08068571,
#        0.07226707, 0.06448952, 0.05733801, 0.05079264, 0.0448295 ,
#        0.03942137, 0.03453857, 0.03014961, 0.02622189, 0.02272223,
#        0.01961746, 0.01687483, 0.01446241, 0.01234943, 0.0105065 ,
#        0.00890582, 0.00752133, 0.00632878, 0.00530579, 0.00443185])

# %%
sigma2 = 2.0

# %%
y2 = (1.0 / (np.sqrt(2.0*np.pi*sigma2)))*np.exp(1.0)**(- (x-m)**2.0/(2.0*sigma2**2.0))

# %%
y2
# Out:
# array([0.09158277, 0.09579769, 0.10011462, 0.10453005, 0.10904004,
#        0.11364022, 0.11832576, 0.12309141, 0.12793147, 0.13283981,
#        0.13780986, 0.14283464, 0.14790675, 0.15301839, 0.15816139,
#        0.1633272 , 0.16850693, 0.17369135, 0.17887096, 0.18403595,
#        0.18917629, 0.19428172, 0.1993418 , 0.20434594, 0.20928343,
#        0.21414348, 0.21891529, 0.22358801, 0.22815088, 0.23259318,
#        0.23690433, 0.24107391, 0.24509172, 0.24894778, 0.25263242,
#        0.25613628, 0.25945038, 0.26256614, 0.26547543, 0.26817059,
#        0.27064447, 0.27289047, 0.27490256, 0.2766753 , 0.27820389,
#        0.27948416, 0.28051262, 0.28128645, 0.28180352, 0.28206241,
#        0.28206241, 0.28180352, 0.28128645, 0.28051262, 0.27948416,
#        0.27820389, 0.2766753 , 0.27490256, 0.27289047, 0.27064447,
#        0.26817059, 0.26547543, 0.26256614, 0.25945038, 0.25613628,
#        0.25263242, 0.24894778, 0.24509172, 0.24107391, 0.23690433,
#        0.23259318, 0.22815088, 0.22358801, 0.21891529, 0.21414348,
#        0.20928343, 0.20434594, 0.1993418 , 0.19428172, 0.18917629,
#        0.18403595, 0.17887096, 0.17369135, 0.16850693, 0.1633272 ,
#        0.15816139, 0.15301839, 0.14790675, 0.14283464, 0.13780986,
#        0.13283981, 0.12793147, 0.12309141, 0.11832576, 0.11364022,
#        0.10904004, 0.10453005, 0.10011462, 0.09579769, 0.09158277])

# %%
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y(x)')
plt.show()

# %%
plt.plot(x,y,x,y2)
plt.xlabel('x')
plt.ylabel('y(x)')
plt.show()

# %%
sigma3 = 3.0
y3 = (1.0 / (np.sqrt(2.0*np.pi*sigma3)))*np.exp(1.0)**(- (x-m)**2.0/(2.0*sigma3**2.0))

# %%
plt.plot(x,y,x,y2,x,y3)
plt.xlabel('x')
plt.ylabel('y(x)')
plt.show()

# %%
x = np.array(['1사분기', '2사분기', '3사분기', '4사분기'])

# %%
y = np.array([234, 254.7, 144.6, 317.6])

# %%
from matplotlib import font_manager,rc

# %%
plt.rcParams['font.family']="Malgun Gothic"
plt.bar(x,y)
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
