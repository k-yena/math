# %%
import sympy as sp

# %%
x=sp.symbols('x')

# %%
# 1. 상수 함수의 미분
f1 = 5

# %%
sp.diff(f1,x)
# Out:
# 0

# %%
# 거듭제곱(역)함수

# %%
f2 = x**4

# %%
sp.diff(f2,x)
# Out:
# 4*x**3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $f(x)=x^2-5x$
# $,$
# $f'(x)=2x-5$

# %%
f3 = x**2-5*x

# %%
sp.diff(f3,x)
# Out:
# 2*x - 5

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
f4 = (3*x**2-1)*(2*x**2+4*x+2)

# %%
sp.diff(f4,x)
# Out:
# 6*x*(2*x**2 + 4*x + 2) + (4*x + 4)*(3*x**2 - 1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $\frac{1}{2}$

# %% [markdown]
# $\frac{2x^2+3x}{x^2+1}의 도함수 f'(x)를 구하세요$

# %%
f5 = (2 *x ** 2 + 3*x)/(x**2+1)

# %%
sp.diff(f5,x)
# Out:
# -2*x*(2*x**2 + 3*x)/(x**2 + 1)**2 + (4*x + 3)/(x**2 + 1)

# %% [markdown]
# $y=(3x^2+2)^2$

# %%
f6 = (3*x**2+2)**2

# %%
sp.diff(f6,x)
# Out:
# 12*x*(3*x**2 + 2)

# %% [markdown]
# $y = \frac{1}{(2x^2+3x-1)^3}$  미분하세요

# %%
f7 = 1/(2*x**2+3*x-1)**3

# %%
sp.diff(f7,x)
# Out:
# (-12*x - 9)/(2*x**2 + 3*x - 1)**4
