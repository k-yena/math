# %% [markdown]
# <a href="https://colab.research.google.com/github/k-yena/math/blob/main/%EC%A7%80%EC%88%98%ED%95%A8%EC%88%98%EC%99%80_%EB%A1%9C%EA%B7%B8%ED%95%A8%EC%88%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
print("%.1f" % np.sqrt(73))
# Out:
# 8.5

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.e    # 2.718281 (암기!!)
# Out:
# 2.718281828459045

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# a > 1 경우

a = 2

math.pow(a,1)   # a의 1승
# math.pow(a,2)   # a의 2승
# Out:
# 2.0

# %%
a ** 2
# Out:
# 4

# %%
a = 0.5

# %%
# 0 < a < 1 경우

math.pow(a,0.5)
# Out:
# 0.7071067811865476

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.e**1
# Out:
# 2.718281828459045

# %%
math.e**2         # 2.718281828459045 * 2.718281828459045
# Out:
# 7.3890560989306495

# %%
math.e**3
# Out:
# 20.085536923187664

# %%
math.exp(1)       # math.e**1와 같음
# Out:
# 2.718281828459045

# %%
math.exp(1) == math.e**1
# Out:
# True

# %%
import numpy as np

# %%
np.exp(1)   # 자연상수
# Out:
# 2.718281828459045

# %%
np.exp(1) == math.e     # 자연상수 or 오일러수( 기호 e로 표기 )
# Out:
# True

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 7.3890560989306495

# %%
np.exp(2)
# Out:
# 7.38905609893065

# %%
np.exp(3)
# Out:
# 20.085536923187668

# %%
# 로지스틱 함수

# %%
1/(1+np.exp(0))    # x가 0일 경우
# Out:
# 0.5

# %%
# 지수와 로그의 관계

# %%
2 ** 3 == 8
# Out:
# True

# %%
np.log2(8)
# Out:
# 3.0

# %%
np.log10(10)
# Out:
# 1.0

# %%
np.log10(100)
# Out:
# 2.0

# %%
np.log(math.e)
# Out:
# 1.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
np.log2(2)+np.log2(3)
# Out:
# 2.584962500721156

# %%
np.log2(6)
# Out:
# 2.584962500721156
